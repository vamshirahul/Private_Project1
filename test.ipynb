# %%
# add temporarily at top of main.py (right after imports)
import streamlit as st
st.sidebar.write("Key found:", "OPENAI_API_KEY" in st.secrets)
# Out:
# 2025-10-07 12:06:05.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 12:06:06.605
# ...
#   command:
#
#     streamlit run d:\VirtualEnv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-10-07 12:06:06.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 12:06:06.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 12:06:06.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 12:06:06.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 12:06:06.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
